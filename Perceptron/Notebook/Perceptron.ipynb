# %% [markdown]
# # Perceptron

# %% [markdown]
# ![Perceptron.png](attachment:c2026472-eb05-4ea9-b707-31b4c85d4523.png)

# %% [markdown]
# \begin{equation}
# \Large \sigma(b + \sum^n w_ix_i) = y
# \end{equation}
